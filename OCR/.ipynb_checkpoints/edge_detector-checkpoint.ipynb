# %%
pip install git+https://github.com/alirezamika/autoscraper.git

# %%
pip install autoscraper

# %%
from autoscraper import AutoScraper

url = 'https://manage.wix.com/dashboard/592edb08-234e-4b95-a51f-1085e75e75fe/home?referralInfo=my-sites'

# We can add one or multiple candidates here.
# You can also put urls here to retrieve urls.
wanted_list = ["Add your first service"]

scraper = AutoScraper()
result = scraper.build(url, wanted_list)
print(result)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread('image2.png')

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Calculate the histogram of the image
hist = cv2.calcHist([gray],[0],None,[256],[0,256])

# Plot the histogram
plt.hist(gray.ravel(),256,[0,256])
plt.show()

# Find the threshold values by finding the peaks in the histogram
# This is a simple approach and may not work for all images
threshold_low = np.argmax(hist[:128])
threshold_high = np.argmax(hist[128:]) + 128

print("Lower threshold:", threshold_low)
print("Upper threshold:", threshold_high)

# %%
import cv2
import numpy as np

# Load the image
imge = cv2.imread("image2.png")

img = cv2.resize(imge,(1340,840))

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Use the Canny edge detector to find edges in the image
edges = cv2.Canny(gray, 250,50,apertureSize=5)#50,150

# Find contours in the edges
contours, hierarchy = cv2.findContours(edges, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# Draw bounding boxes around each contour
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Display the result
cv2.imshow("Bounding Boxes", img)
key = cv2.waitKey(0)
if key == ord("q"):
    cv2.destroyAllWindows()
# In this example, the image is first loaded using cv2.imread(), and then converted to grayscale using cv2.cvtColor(). The cv2.Canny() function is used to find edges in the image, and cv2.findContours() is used to find contours in the edges. Finally, bounding boxes are drawn around each contour using cv2.rectangle(). The result is displayed using

# %%
import cv2
import numpy as np

# Load the image
imge = cv2.imread("image.png", cv2.IMREAD_GRAYSCALE)

img = cv2.resize(imge,(1340,840))
# Apply the Sobel operator to the image
sobel_x = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
# sobel_y = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)

# Combine the Sobel results to get the final edge map
sobel = np.sqrt(np.square(sobel_x) + np.square(sobel_y))

# Normalize the Sobel results to the range [0, 255]
sobel = (sobel / np.max(sobel)) * 255
sobel = sobel.astype(np.uint8)

# Display the result
cv2.imshow("Sobel Edge Map", sobel)
key = cv2.waitKey(0)
if key == ord("q"):
    cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the image
image = cv2.imread("image.png")

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to the grayscale image to enhance the text
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]

# Find contours in the thresholded image
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Loop over the contours and draw a bounding box around the text
for c in contours:
    x, y, w, h = cv2.boundingRect(c)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 255), 2)

# Display the image with bounding boxes
cv2.imshow("Image with bounding boxes", image)
cv2.waitKey(0)
key = cv2.waitKey(0)
if key == ord("q"):
    cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the input image
img = cv2.imread("image.png")

if img is None:
    print("Error: Image not loaded.")
else:
    print("Image loaded successfully.")

# Define the text to be added
text = "Example text"

# Define the font and text properties
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 1.0
font_thickness = 2
text_size, baseline = cv2.getTextSize(text, font, font_scale, font_thickness)

# Define the starting point for the text
text_x = 100
text_y = 100 + text_size[1]

# Draw the text on the image
cv2.putText(img, text, (text_x, text_y), font, font_scale, (0, 0, 0), font_thickness)

# Draw a bounding box around the text
cv2.rectangle(img, (text_x, text_y - text_size[1]), (text_x + text_size[0], text_y), (0, 0, 255), 2)

# Save the output image
# cv2.imwrite("image.png", img)
cv2.imshow("Image with bounding boxes", img)
cv2.waitKey(0)
key = cv2.waitKey(0)
if key == ord("q"):
    cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the input image
img = cv2.imread("image.png")

# Define the text to be added
text = "Example text \n Another line of text"

# Define the font and text properties
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 1.0
font_thickness = 2

# Split the text into rows
rows = text.split("\n")

# Loop over each row of text
for i, row in enumerate(rows):
    # Get the size of the text in pixels
    text_size, baseline = cv2.getTextSize(row, font, font_scale, font_thickness)

    # Define the starting point for the text
    text_x = 100
    text_y = 100 + i * text_size[1] + i * 10

    # Draw the text on the image
    cv2.putText(img, row, (text_x, text_y), font, font_scale, (255, 255, 255), font_thickness)

    # Draw a bounding box around the text
    cv2.rectangle(img, (text_x, text_y - text_size[1]), (text_x + text_size[0], text_y), (0, 0, 255), 2)

# Save the output image
# cv2.imwrite("output.jpg", img)
cv2.imshow("Image with bounding boxes", img)
cv2.waitKey(0)
key = cv2.waitKey(0)
if key == ord("q"):
    cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
    
image = cv2.imread("image.png")
mask = np.zeros(image.shape, dtype=np.uint8)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (3,3), 0)
thresh = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,51,9)

# Create horizontal kernel then dilate to connect text contours
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
dilate = cv2.dilate(thresh, kernel, iterations=2)

# Find contours and filter out noise using contour approximation and area filtering
cnts = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.04 * peri, True)
    x,y,w,h = cv2.boundingRect(c)
    area = w * h
    ar = w / float(h)
    if area > 1200 and area < 50000 and ar <8:
        cv2.drawContours(mask, [c], -1, (255,255,255), -1)
        
# Bitwise-and input image and mask to get result
mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
result = cv2.bitwise_and(image, image, mask=mask)
result[mask==0] = (255,255,255) # Color background white

# NEW CODE HERE TO END _____________________________________________________________
gray2 = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)
thresh2 = cv2.threshold(gray2, 128, 255, cv2.THRESH_BINARY)[1]
thresh2 = 255 - thresh2
kernel = np.ones((5 ,191), np.uint8)
close = cv2.morphologyEx(thresh2, cv2.MORPH_CLOSE, kernel)

# get external contours
contours = cv2.findContours(close, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
contours = contours[0] if len(contours) == 2 else contours[1]

# draw contours
result2 = result.copy()
for cntr in contours:
    # get bounding boxes
    pad = 10
    x,y,w,h = cv2.boundingRect(cntr)
    cv2.rectangle(result2, (x-pad, y-pad), (x+w+pad, y+h+pad), (0, 0, 255), 4)

cv2.imwrite("image.png", result2)

cv2.imshow("mask",mask)
cv2.imshow("thresh",thresh)
cv2.imshow("dilate",dilate)
cv2.imshow("result",result)
cv2.imshow("gray2",gray2)
cv2.imshow("thresh2",thresh2)
cv2.imshow("close",close)
cv2.imshow("result2",result2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the input image
img = cv2.imread("image2.png")
img = cv2.resize(img,(1340,840))

# Define the text to be added
text = "Example"

# Define the font and text properties
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 1.0
font_thickness = 2

# Split the text into rows
rows = text.split("\n")

# Get the size of the whole block of text in pixels
text_height = 0
text_width = 0
for row in rows:
    text_size, baseline = cv2.getTextSize(row, font, font_scale, font_thickness)
    text_width = max(text_width, text_size[0])
    text_height += text_size[1] + 10

# Define the starting point for the text
text_x = 100
text_y = 100

# Loop over each row of text
for i, row in enumerate(rows):
    # Get the size of the text in pixels
    text_size, baseline = cv2.getTextSize(row, font, font_scale, font_thickness)

    # Draw the text on the image
    cv2.putText(img, row, (text_x, text_y), font, font_scale, (0, 0, 0), font_thickness)

    # Update the y-coordinate for the next row of text
    text_y += text_size[1] + 10

# Draw a bounding box around the whole block of text
cv2.rectangle(img, (text_x, text_y - text_height), (text_x + text_width, text_y), (0, 0, 255), 2)

# Save the output image
cv2.imwrite("image2.png", img)
cv2.imshow("Image with bounding boxes", img)
cv2.waitKey(0)
key = cv2.waitKey(0)
if key == ord("q"):
    cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the input image
img = cv2.imread("3.png")

# Define the text to be added
text = pytesseract.image_to_string(img)

# Define the font and text properties
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 1.0
font_thickness = 2

# Split the text into rows
# rows = text.split("\n")

# Get the size of the whole block of text in pixels
text_height = 0
text_width = 0
for row in text.split("\n"):
    text_size, baseline = cv2.getTextSize(row, font, font_scale, font_thickness)
    text_width = max(text_width, text_size[0])
    text_height += text_size[1] + 10

# Define the starting point for the text
text_x = 100
text_y = 100

# Loop over each row of text
# for i, row in enumerate(rows):
for row in text.split("\n"):
    # Get the size of the text in pixels
    text_size, baseline = cv2.getTextSize(row, font, font_scale, font_thickness)

    # Draw the text on the image
    cv2.putText(img, row, (text_x, text_y), font, font_scale, (0, 0, 0), font_thickness)

    # Update the y-coordinate for the next row of text
    text_y += text_size[1] + 10

# Draw a bounding box around the whole block of text
start_x = text_x
end_x = text_x + text_width
start_y = text_y - text_height
end_y = text_y
cv2.rectangle(img, (start_x, start_y), (end_x, end_y), (0, 0, 255), 2)

# Save the output image
# cv2.imwrite("image2.png", img)
cv2.imshow("Image with bounding boxes", img)
cv2.waitKey(0)
key = cv2.waitKey(0)
if key == ord("q"):
    cv2.destroyAllWindows()

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\Pathora\AppData\Local\Programs\Tesseract-OCR\tesseract.exe'

# %%
import cv2
import pytesseract

# Load the input image
image = cv2.imread("3.png")
img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# Perform OCR on the image to extract the text
text = pytesseract.image_to_string(img)

# Define the font and text properties
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 1.0
font_thickness = 2

# Get the size of the text in pixels
text_size, baseline = cv2.getTextSize(text, font, font_scale, font_thickness)

# Define the starting point for the text
text_x = 10
text_y = 10

# Draw the text on the image
cv2.putText(img, text, (text_x, text_y), font, font_scale, (255, 255, 255), font_thickness)

# Draw a bounding box around the text
start_x = text_x
end_x = text_x + text_size[0]
start_y = text_y
end_y = text_y + text_size[1]
cv2.rectangle(img, (start_x, start_y), (end_x, end_y), (0, 0, 255), 2)

# Save the output image
# cv2.imwrite("image2.png", img)
cv2.imshow("Image with bounding boxes", img)
cv2.waitKey(0)
key = cv2.waitKey(0)
if key == ord("q"):
    cv2.destroyAllWindows()

# %%
print(text)

# %%
for i in text.split("\n"):
    print(i,"============")

# %%
import cv2
import pytesseract

# Load the input image
img = cv2.imread("3.png")
img = cv2.resize(img,(1320,840))

# Perform OCR on the image to extract the text
text = pytesseract.image_to_string(img)

# Split the text into separate lines based on the newline character
lines = text.split("\n")

# Define the font and text properties
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 1.0
font_thickness = 2

# Define the starting point for the text
text_x = 0
text_y = 0 + (i * text_size[1] * 1)

# Loop through each line of text
for i, line in enumerate(lines):
    # Get the size of the text in pixels
    text_size, baseline = cv2.getTextSize(line, font, font_scale, font_thickness)
    
    #
    # Calculate the width of the line
    text_width = cv2.getTextSize(line, font, font_scale, font_thickness)[0][0]
    
    # Define the starting point for the text
#     text_x = 0
#     text_y = 0 + (i * text_size[1] * 1)

    # Draw the text on the image
    cv2.putText(img, line, (int(text_x), int(text_y)), font, font_scale, (0, 0,0), font_thickness)

    # Draw a bounding box around the text
    start_x = text_x
    end_x = text_x + text_size[0]
    start_y = text_y
    end_y = text_y + text_size[1]
    cv2.rectangle(img, (int(start_x), int(start_y)), (int(end_x),int( end_y)), (0, 0, 255), 2)

# Save the output image
# cv2.imwrite("output.jpg", img)
cv2.imshow("Image with bounding boxes", img)
cv2.waitKey(0)
key = cv2.waitKey(0)
if key == ord("q"):
    cv2.destroyAllWindows()

# %%
lines

# %%
import cv2
import numpy as np

# Load the image
img = cv2.imread('3.png')

# Define the font type, font scale, font thickness, and text color
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 1
font_thickness = 2
text_color = (255, 255, 255)

# Define the starting point for the text
text_x = 100
text_y = 100

# Define the text to be displayed
text = pytesseract.image_to_string(img)

# Split the text into lines
lines = text.split("\n")

# Calculate the height of the text
text_height = cv2.getTextSize(text, font, font_scale, font_thickness)[0][1]

# Loop through each line of text
for i, line in enumerate(lines):
    # Calculate the width of the line
    text_width = cv2.getTextSize(line, font, font_scale, font_thickness)[0][0]
    
    # Draw the text on the image
    cv2.putText(img, line, (text_x, text_y), font, font_scale, text_color, font_thickness)
    
    # Draw the bounding box around the text
    cv2.rectangle(img, (text_x, text_y - text_height), (text_x + text_width, text_y), (255, 0, 0), 2)
    
    # Update the starting point for the next line
    text_y += text_height + 10

# Save the image
cv2.imwrite('sample_output.jpg', img)

# %%
import cv2
import pytesseract

# Load the image
image = cv2.imread("3.png")

# Perform OCR on the image
text = pytesseract.image_to_string(image)

# Get the bounding box information from the OCR output
boxes = pytesseract.image_to_boxes(image)

# Draw a box around the text in the image
for b in boxes.splitlines():
    # Get the bounding box coordinates
    b = b.split("\n")
    x, y, w, h = int(b[1]), int(b[2]), int(b[3]), int(b[4])
    
    # Draw the box
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 255), 2)

# Show the image with the bounding box
cv2.imshow("OCR output", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 17
#      14 for b in boxes.splitlines():
#      15     # Get the bounding box coordinates
#      16     b = b.split("\n")
# ---> 17     x, y, w, h = int(b[1]), int(b[2]), int(b[3]), int(b[4])
#      19     # Draw the box
#      20     cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 255), 2)
#
# IndexError: list index out of range

# %%
boxes.splitlines()
# Out:
# ['@ 23 1051 37 1060 0',
#  'M 51 1054 55 1065 0',
#  'i 51 1054 62 1065 0',
#  'c 64 1054 74 1065 0',
#  'r 73 1054 80 1065 0',
#  'o 75 1054 87 1062 0',
#  '| 103 1046 104 1070 0',
#  'e 113 1053 133 1065 0',
#  '5 143 1054 148 1065 0',
#  'G 155 1054 164 1065 0',
#  'r 161 1046 169 1073 0',
#  'e 166 1054 178 1062 0',
#  'e 179 1054 181 1059 0',
#  '| 195 1046 196 1070 0',
#  'e 1354 998 1360 1032 0',
#  'i 1359 998 1369 1032 0',
#  'd 1368 998 1377 1032 0',
#  '= 1376 998 1388 1032 0',
#  'c 1388 998 1397 1032 0',
#  'h 1396 998 1408 1032 0',
#  'r 1407 998 1417 1032 0',
#  'o 1416 998 1428 1032 0',
#  'm 1427 998 1437 1032 0',
#  'e 1436 998 1448 1032 0',
#  '& 1447 998 1456 1032 0',
#  'i 1456 998 1468 1032 0',
#  'e 1467 998 1476 1032 0',
#  '= 1475 998 1485 1032 0',
#  'U 1484 998 1496 1032 0',
#  'T 1495 998 1507 1032 0',
#  'F 1507 998 1516 1032 0',
#  '- 1515 998 1524 1032 0',
#  '8 1524 998 1536 1032 0',
#  '™ 19 967 37 980 0',
#  'G 48 969 57 980 0',
#  'm 55 969 65 980 0',
#  'a 59 969 70 977 0',
#  'i 71 969 81 977 0',
#  'l 83 969 85 980 0',
#  '@ 107 967 117 981 0',
#  '% 106 967 126 981 0',
#  'Y 136 969 145 980 0',
#  'o 144 969 152 977 0',
#  'u 153 969 160 977 0',
#  'T 161 969 168 980 0',
#  'u 169 969 176 977 0',
#  'b 178 969 185 980 0',
#  'e 186 969 193 977 0',
#  'B 216 966 225 984 0',
#  'F 216 966 234 984 0',
#  'M 245 969 256 980 0',
#  'a 258 969 264 977 0',
#  'p 262 966 270 980 0',
#  's 266 966 280 977 0',
#  '~ 1715 868 1864 908 0',
#  'G 55 877 83 906 0',
#  'o 84 877 103 896 0',
#  'o 104 877 123 896 0',
#  'g 114 865 134 910 0',
#  'l 124 869 148 905 0',
#  'e 150 877 167 896 0',
#  'b 251 884 261 899 0',
#  'e 262 884 272 895 0',
#  's 273 884 282 895 0',
#  't 283 884 288 899 0',
#  'e 294 884 304 895 0',
#  'd 305 884 315 899 0',
#  'g 316 880 326 895 0',
#  'e 327 884 338 895 0',
#  'd 344 884 354 899 0',
#  'e 350 884 360 899 0',
#  't 355 884 365 895 0',
#  'e 366 884 372 899 0',
#  'c 372 884 382 895 0',
#  't 383 884 393 895 0',
#  'i 393 884 402 899 0',
#  'o 403 884 413 895 0',
#  'n 415 884 424 895 0',
#  'a 431 884 441 895 0',
#  'l 443 884 445 899 0',
#  'g 446 880 456 895 0',
#  'o 458 884 468 895 0',
#  'r 469 884 475 895 0',
#  'i 476 884 485 899 0',
#  't 483 880 490 899 0',
#  'h 486 884 495 899 0',
#  'm 497 884 512 895 0',
#  'x 884 881 900 898 0',
#  '& 944 877 962 902 0',
#  'O 990 878 1016 901 0',
#  'a 1041 880 1062 901 0',
#  'Q 251 804 264 820 0',
#  'A 272 804 281 820 0',
#  'l 276 807 290 820 0',
#  'l 292 807 294 820 0',
#  '( 326 804 342 820 0',
#  'V 351 807 365 820 0',
#  'i 360 804 369 820 0',
#  'd 366 807 375 820 0',
#  'e 380 804 389 820 0',
#  'o 376 807 404 816 0',
#  's 400 804 404 820 0',
#  'J 436 804 452 820 0',
#  'I 462 807 464 820 0',
#  'm 466 807 489 816 0',
#  'a 479 803 491 820 0',
#  'g 490 803 499 816 0',
#  'e 500 807 509 816 0',
#  's 510 807 518 816 0',
#  '< 550 804 559 820 0',
#  'S 575 807 584 820 0',
#  'h 585 807 593 820 0',
#  'o 594 807 604 816 0',
#  'p 604 803 613 820 0',
#  'p 605 803 625 816 0',
#  'i 626 807 638 820 0',
#  'n 639 803 648 816 0',
#  'g 646 803 648 820 0',
#  'N 681 805 717 820 0',
#  'e 714 805 729 820 0',
#  'w 718 807 749 816 0',
#  's 740 805 749 820 0',
#  ': 782 805 786 819 0',
#  'M 795 807 808 820 0',
#  'o 809 807 819 816 0',
#  'r 816 805 825 820 0',
#  'e 820 807 835 816 0',
#  'T 1023 807 1032 820 0',
#  'o 1030 807 1036 820 0',
#  'o 1031 807 1051 816 0',
#  'l 1052 807 1054 820 0',
#  's 1055 807 1063 816 0',
#  '~ 249 785 294 789 0',
#  'A 249 753 256 766 0',
#  'b 249 753 261 766 0',
#  'o 262 753 271 766 0',
#  'u 272 753 282 762 0',
#  't 283 753 298 765 0',
#  '4 303 753 312 765 0',
#  ', 313 751 316 755 0',
#  '6 317 753 326 765 0',
#  '3 327 753 336 765 0',
#  ', 336 751 339 755 0',
#  '0 340 753 351 765 0',
#  '0 352 753 362 765 0',
#  ', 363 751 366 755 0',
#  '0 367 753 377 765 0',
#  '0 374 751 384 765 0',
#  '0 378 753 400 765 0',
#  'r 405 753 408 766 0',
#  'e 405 753 420 762 0',
#  's 416 753 425 766 0',
#  'u 421 753 429 762 0',
#  'l 430 753 438 762 0',
#  't 439 753 448 766 0',
#  's 449 753 457 762 0',
#  '( 462 751 467 767 0',
#  '0 468 753 478 765 0',
#  '. 479 753 482 755 0',
#  '5 483 753 492 765 0',
#  '0 493 753 503 765 0',
#  's 508 753 516 762 0',
#  'e 516 753 535 762 0',
#  'c 528 751 536 767 0',
#  'o 536 753 555 762 0',
#  'n 546 751 555 767 0',
#  'd 556 753 565 766 0',
#  's 566 753 574 762 0',
#  ') 575 751 579 767 0',
#  'T 249 702 261 717 0',
#  'h 262 702 271 717 0',
#  'e 273 702 283 713 0',
#  'C 289 702 303 717 0',
#  'a 304 702 314 713 0',
#  'n 316 702 326 713 0',
#  'n 328 702 338 713 0',
#  'y 339 698 350 713 0',
#  'E 357 702 368 717 0',
#  'd 366 698 376 717 0',
#  'g 370 702 380 717 0',
#  'e 382 698 404 713 0',
#  'D 411 702 424 717 0',
#  'e 418 702 428 717 0',
#  't 425 702 435 713 0',
#  'e 436 702 453 717 0',
#  'c 447 702 457 717 0',
#  't 454 702 464 713 0',
#  'i 465 702 476 717 0',
#  'o 478 702 489 713 0',
#  'n 490 702 500 713 0',
#  'a 507 702 517 713 0',
#  'l 519 702 523 717 0',
#  'g 524 698 535 713 0',
#  'o 533 698 542 717 0',
#  'r 536 702 548 713 0',
#  'i 549 702 560 717 0',
#  't 561 702 568 717 0',
#  'h 569 702 579 717 0',
#  'm 581 702 597 713 0',
#  'i 604 702 607 717 0',
#  's 608 702 617 713 0',
#  'a 624 702 634 713 0',
#  'w 640 702 655 713 0',
#  'i 656 702 658 717 0',
#  'd 660 702 669 717 0',
#  'e 671 702 681 713 0',
#  'l 682 702 685 717 0',
#  'y 686 698 696 713 0',
#  'u 702 702 711 713 0',
#  's 713 702 722 713 0',
#  'e 723 702 733 713 0',
#  'd 734 702 744 717 0',
#  'e 751 702 761 713 0',
#  'd 762 702 771 717 0',
#  'g 769 698 779 717 0',
#  'e 773 698 794 713 0',
#  'd 801 702 810 717 0',
#  'e 807 702 817 717 0',
#  't 812 702 822 713 0',
#  'e 822 702 828 717 0',
#  'c 829 702 839 713 0',
#  't 840 702 849 713 0',
#  'i 849 702 858 717 0',
#  'o 860 702 870 713 0',
#  'n 871 702 881 713 0',
#  'a 887 702 897 713 0',
#  'l 899 702 902 717 0',
#  'g 903 698 913 713 0',
#  'o 914 702 924 713 0',
#  'r 920 698 929 717 0',
#  'i 926 702 935 717 0',
#  't 935 698 945 717 0',
#  'h 936 702 952 717 0',
#  'm 954 702 968 713 0',
#  'i 976 702 978 717 0',
#  'n 980 702 989 713 0',
#  't 996 702 1002 717 0',
#  'o 1002 702 1012 713 0',
#  'd 1013 702 1023 717 0',
#  'a 1024 702 1034 713 0',
#  'y 1030 698 1040 717 0',
#  "' 1035 698 1048 717 0",
#  's 1049 702 1058 713 0',
#  'i 250 671 252 686 0',
#  'm 254 671 269 682 0',
#  'a 271 671 281 682 0',
#  'g 277 667 287 686 0',
#  'e 282 667 303 682 0',
#  'p 310 667 316 686 0',
#  'r 310 667 320 682 0',
#  'o 321 671 327 682 0',
#  'c 333 667 343 686 0',
#  'e 327 671 359 682 0',
#  's 354 667 363 686 0',
#  's 359 671 368 682 0',
#  'i 369 671 378 682 0',
#  'n 380 671 394 686 0',
#  'g 395 667 405 682 0',
#  'a 412 667 417 686 0',
#  'p 412 671 422 682 0',
#  'p 423 667 433 682 0',
#  'l 434 667 444 682 0',
#  'i 446 671 453 686 0',
#  'c 453 667 462 686 0',
#  'a 454 671 474 682 0',
#  't 468 667 478 686 0',
#  'i 475 671 484 686 0',
#  'o 485 671 495 682 0',
#  'n 497 671 506 682 0',
#  's 502 667 510 686 0',
#  '. 507 671 521 682 0',
#  'I 529 671 532 686 0',
#  't 534 671 539 686 0',
#  'w 545 671 559 682 0',
#  'o 560 671 570 682 0',
#  'r 571 671 577 682 0',
#  'k 578 671 587 686 0',
#  's 587 671 596 682 0',
#  'i 603 671 606 686 0',
#  'n 608 671 617 682 0',
#  'm 625 671 639 682 0',
#  'u 635 667 645 686 0',
#  'l 641 671 650 682 0',
#  't 652 671 655 686 0',
#  'i 656 671 665 686 0',
#  'p 667 667 677 682 0',
#  'l 678 671 680 686 0',
#  'e 682 671 692 682 0',
#  's 699 671 708 682 0',
#  't 708 671 714 686 0',
#  'a 714 671 724 682 0',
#  'g 725 667 735 682 0',
#  'e 736 671 747 682 0',
#  's 747 671 756 682 0',
#  'a 763 671 773 682 0',
#  's 774 671 783 682 0',
#  's 790 671 799 682 0',
#  'h 800 671 809 686 0',
#  'o 811 671 821 682 0',
#  'w 817 671 829 686 0',
#  'n 821 671 846 682 0',
#  'i 854 671 855 686 0',
#  'n 854 671 867 686 0',
#  'f 874 667 879 686 0',
#  'i 874 671 883 686 0',
#  'g 884 667 894 682 0',
#  '1 902 671 908 686 0',
#  '. 913 671 916 673 0',
#  '2 918 671 928 686 0',
#  '. 930 671 932 673 0',
#  'C 940 671 953 686 0',
#  'a 954 671 964 682 0',
#  'n 966 671 975 682 0',
#  'n 977 671 986 682 0',
#  'y 987 667 997 682 0',
#  'e 1003 671 1013 682 0',
#  'd 1014 671 1024 686 0',
#  'g 1025 667 1035 682 0',
#  'e 1037 671 1047 682 0',
#  'd 249 640 259 655 0',
#  'e 256 640 266 655 0',
#  't 261 640 271 651 0',
#  'e 271 640 287 655 0',
#  'c 283 640 293 655 0',
#  't 288 640 298 651 0',
#  'i 298 640 307 655 0',
#  'o 308 640 319 651 0',
#  'n 320 640 329 651 0',
#  'a 336 640 346 651 0',
#  'l 348 640 350 655 0',
#  'g 352 636 361 651 0',
#  'o 359 636 369 655 0',
#  'r 363 640 373 651 0',
#  'i 374 640 384 655 0',
#  't 385 640 390 655 0',
#  'h 391 640 400 655 0',
#  'm 402 640 417 651 0',
#  'p 424 636 434 651 0',
#  'r 436 640 442 651 0',
#  'o 442 640 452 651 0',
#  'd 453 640 462 655 0',
#  'u 465 640 474 651 0',
#  'c 474 636 484 655 0',
#  'e 475 640 495 651 0',
#  's 496 640 505 651 0',
#  's 512 640 521 651 0',
#  'm 522 640 537 651 0',
#  'o 533 637 542 655 0',
#  'o 538 640 549 651 0',
#  't 550 640 560 651 0',
#  'h 560 640 566 655 0',
#  'e 567 640 576 655 0',
#  'r 577 640 588 651 0',
#  ', 589 637 598 651 0',
#  't 605 640 610 655 0',
#  'h 611 640 620 655 0',
#  'i 622 640 625 655 0',
#  'n 627 640 636 651 0',
#  'n 638 640 647 651 0',
#  'e 645 637 655 655 0',
#  'r 649 640 659 651 0',
#  ', 660 637 669 651 0',
#  'a 676 640 686 651 0',
#  'n 688 640 697 651 0',
#  'd 699 640 708 655 0',
#  'c 715 640 725 651 0',
#  'l 726 640 728 655 0',
#  'e 730 640 740 651 0',
#  'a 741 640 751 651 0',
#  'n 752 640 762 651 0',
#  'e 763 640 773 651 0',
#  'r 775 640 781 651 0',
#  'i 787 640 789 655 0',
#  'm 791 640 806 651 0',
#  'a 808 640 818 651 0',
#  'g 819 636 828 651 0',
#  'e 830 640 840 651 0',
#  's 841 640 850 651 0',
#  't 856 640 862 655 0',
#  'h 863 640 872 655 0',
#  'a 873 640 883 651 0',
#  'n 885 640 894 651 0',
#  'S 901 640 913 655 0',
#  'o 914 640 925 651 0',
#  'b 920 640 932 655 0',
#  'e 926 640 936 655 0',
#  'l 937 640 951 655 0',
#  'a 958 640 968 651 0',
#  'n 969 640 979 651 0',
#  'd 980 640 989 655 0',
#  'P 997 640 1009 655 0',
#  'r 1010 640 1017 651 0',
#  'e 1017 640 1027 651 0',
#  'w 1023 640 1033 655 0',
#  'i 1027 640 1042 651 0',
#  't 1043 640 1045 655 0',
#  't 1046 640 1057 655 0',
#  'f 249 610 254 625 0',
#  'i 249 610 258 625 0',
#  'l 260 610 262 625 0',
#  't 263 610 269 625 0',
#  'e 269 610 280 621 0',
#  'r 281 610 296 621 0',
#  's 290 610 297 625 0',
#  '. 298 610 301 612 0',
#  '0 313 610 320 621 0',
#  '7 321 610 329 621 0',
#  '- 329 613 334 614 0',
#  'A 334 610 344 621 0',
#  'u 345 610 352 618 0',
#  'g 353 607 360 618 0',
#  '- 361 613 366 614 0',
#  '2 366 610 374 621 0',
#  '0 374 610 382 621 0',
#  '2 383 610 390 621 0',
#  '2 391 610 399 621 0',
#  'h 250 553 255 570 0',
#  't 250 557 258 570 0',
#  't 259 553 278 570 0',
#  'p 270 553 277 570 0',
#  's 279 557 287 567 0',
#  ': 288 557 291 566 0',
#  '/ 292 557 297 570 0',
#  'M 301 553 307 570 0',
#  'w 306 553 315 570 0',
#  'w 297 557 340 570 0',
#  'w 325 553 334 570 0',
#  '. 340 557 342 559 0',
#  'a 344 557 353 567 0',
#  'n 350 553 359 570 0',
#  'a 354 557 362 567 0',
#  'l 363 557 375 570 0',
#  'y 375 553 384 570 0',
#  't 377 553 390 570 0',
#  'i 391 557 393 570 0',
#  'c 394 557 411 567 0',
#  's 405 553 411 570 0',
#  'v 412 557 420 567 0',
#  'i 421 557 423 570 0',
#  'd 424 557 433 570 0',
#  'h 435 557 443 570 0',
#  'y 444 553 452 567 0',
#  'a 453 557 462 567 0',
#  '. 463 557 466 559 0',
#  'c 467 557 485 567 0',
#  'o 477 553 488 570 0',
#  'm 486 557 500 567 0',
#  '> 506 558 510 566 0',
#  'b 516 557 525 570 0',
#  'l 526 557 528 570 0',
#  'o 530 553 548 567 0',
#  'g 540 553 548 570 0',
#  '» 556 558 558 566 0',
#  '2 565 557 574 570 0',
#  '0 574 557 583 570 0',
#  '2 584 557 593 570 0',
#  '2 592 557 601 570 0',
#  '/ 594 557 608 570 0',
#  '0 608 557 617 570 0',
#  '8 618 557 627 570 0',
#  '» 633 558 637 566 0',
#  'c 643 557 661 567 0',
#  'o 653 557 662 567 0',
#  'm 661 557 670 567 0',
#  '. 662 557 676 567 0',
#  '. 677 557 680 559 0',
#  '. 682 557 690 559 0',
#  'C 250 519 266 537 0',
#  'o 268 519 280 532 0',
#  'm 283 519 300 532 0',
#  'p 295 514 309 537 0',
#  'r 304 514 315 532 0',
#  'e 318 519 337 532 0',
#  'h 333 514 345 537 0',
#  'e 340 519 350 537 0',
#  'n 353 519 365 532 0',
#  's 368 519 378 532 0',
#  'i 381 519 392 532 0',
#  'v 394 519 410 537 0',
#  'e 411 519 423 532 0',
#  'G 432 519 449 537 0',
#  'u 444 519 458 537 0',
#  'i 452 519 469 537 0',
#  'd 471 519 482 537 0',
#  'e 485 519 497 532 0',
#  't 505 519 512 536 0',
#  'o 513 519 525 532 0',
#  'E 535 519 548 537 0',
#  'd 550 519 562 537 0',
#  'g 564 514 576 532 0',
#  'e 578 519 590 532 0',
#  'D 600 519 615 537 0',
#  'e 610 519 621 537 0',
#  't 617 519 629 532 0',
#  'e 630 519 637 536 0',
#  'c 638 519 650 532 0',
#  't 652 519 663 532 0',
#  'i 664 519 674 537 0',
#  'o 677 519 689 532 0',
#  'n 691 519 702 532 0',
#  'A 709 519 726 537 0',
#  'l 728 519 730 537 0',
#  'g 732 514 744 532 0',
#  'o 746 519 759 532 0',
#  'r 761 519 768 532 0',
#  'i 769 519 772 537 0',
#  't 774 519 792 537 0',
#  'h 788 514 802 537 0',
#  'm 796 519 813 532 0',
#  's 816 519 827 532 0',
#  '@ 749 472 765 488 0',
#  'A 770 465 782 496 0',
#  'b 777 475 787 486 0',
#  'o 788 475 795 486 0',
#  'u 796 475 803 483 0',
#  't 805 475 815 485 0',
#  'f 819 465 826 496 0',
#  'e 820 475 832 486 0',
#  'a 833 475 841 483 0',
#  't 840 465 846 496 0',
#  'u 841 475 853 485 0',
#  'r 855 475 859 483 0',
#  'e 858 465 867 496 0',
#  'd 859 475 875 486 0',
#  's 881 475 887 483 0',
#  'n 888 475 895 483 0',
#  'i 896 475 898 483 0',
#  'p 900 472 907 483 0',
#  'p 908 472 915 483 0',
#  'e 916 475 923 483 0',
#  't 924 475 935 485 0',
#  's 931 465 942 496 0',
#  '+ 951 478 955 482 0',
#  'J 973 474 978 486 0',
#  'M 973 474 986 486 0',
#  'F 999 475 1007 486 0',
#  'e 1008 475 1015 483 0',
#  'e 1013 475 1025 486 0',
#  'd 1016 475 1032 486 0',
#  'b 1031 475 1040 486 0',
#  'a 1033 475 1049 486 0',
#  'c 1049 475 1056 483 0',
#  'k 1057 475 1064 486 0',
#  'P 251 386 264 406 0',
#  'e 265 386 279 400 0',
#  'o 280 386 295 400 0',
#  'p 289 380 301 406 0',
#  'l 297 380 316 406 0',
#  'e 318 386 333 400 0',
#  'a 340 386 353 400 0',
#  'l 355 386 358 406 0',
#  's 360 386 372 400 0',
#  'o 374 386 389 400 0',
#  'a 396 386 409 400 0',
#  's 411 386 423 400 0',
#  'k 425 386 437 406 0',
#  'W 249 334 259 349 0',
#  'h 249 334 268 349 0',
#  'i 269 334 278 349 0',
#  'c 280 334 282 349 0',
#  'h 284 334 304 349 0',
#  'i 311 334 314 349 0',
#  's 315 334 324 345 0',
#  't 330 334 336 349 0',
#  'h 337 334 346 349 0',
#  'e 347 334 357 345 0',
#  'b 364 334 374 349 0',
#  'e 375 334 385 345 0',
#  's 386 334 395 345 0',
#  't 396 334 401 349 0',
#  'm 408 334 423 345 0',
#  'e 424 334 434 345 0',
#  't 435 334 440 349 0',
#  'h 441 334 450 349 0',
#  'o 452 334 462 345 0',
#  'd 463 334 472 349 0',
#  'a 480 334 490 345 0',
#  'm 491 334 506 345 0',
#  'o 501 330 513 345 0',
#  'n 507 334 518 345 0',
#  'g 519 330 539 345 0',
#  'b 547 334 551 349 0',
#  'a 547 334 567 349 0',
#  's 560 334 572 349 0',
#  'i 569 334 578 345 0',
#  'c 579 334 593 349 0',
#  'e 599 334 609 345 0',
#  'd 610 334 619 349 0',
#  'g 621 330 630 345 0',
#  'e 632 334 642 345 0',
#  'd 649 334 658 349 0',
#  'e 656 334 666 349 0',
#  't 660 334 676 349 0',
#  'e 674 334 684 349 0',
#  'c 676 334 697 345 0',
#  't 697 334 703 349 0',
#  'i 704 334 706 349 0',
#  'o 707 334 718 345 0',
#  'n 719 334 728 345 0',
#  'a 735 334 745 345 0',
#  'n 747 334 756 345 0',
#  'd 758 334 767 349 0',
#  'w 774 334 788 345 0',
#  'h 789 334 798 349 0',
#  'y 800 330 809 345 0',
#  '? 810 334 820 349 0',
#  'v 1042 336 1056 345 0',
#  'W 249 279 268 294 0',
#  'h 260 279 270 294 0',
#  'a 269 279 278 294 0',
#  't 279 279 296 294 0',
#  'a 302 279 312 290 0',
#  'r 313 279 320 290 0',
#  'e 319 279 330 290 0',
#  't 336 279 341 294 0',
#  'h 342 279 351 294 0',
#  'e 353 279 363 290 0',
#  'm 370 279 385 290 0',
#  'o 386 279 396 290 0',
#  's 397 279 406 290 0',
#  't 407 279 413 294 0',
#  'c 418 279 439 290 0',
#  'o 434 279 446 290 0',
#  'm 440 279 455 290 0',
#  'm 457 279 471 290 0',
#  'o 465 279 477 290 0',
#  'n 473 279 494 290 0',
#  'e 501 275 506 294 0',
#  'd 501 279 521 294 0',
#  'g 517 275 527 294 0',
#  'e 523 275 544 290 0',
#  'd 551 279 556 294 0',
#  'e 551 279 560 294 0',
#  't 562 279 572 290 0',
#  'e 572 279 578 294 0',
#  'c 578 279 589 290 0',
#  't 590 279 599 290 0',
#  'i 599 279 608 294 0',
#  'o 610 279 620 290 0',
#  'n 621 279 630 290 0',
#  'a 637 279 647 290 0',
#  'l 649 279 652 294 0',
#  'g 653 275 663 290 0',
#  'o 664 279 674 290 0',
#  'r 670 275 680 294 0',
#  'i 676 279 685 294 0',
#  't 686 279 702 294 0',
#  'h 697 275 707 294 0',
#  'm 704 279 718 290 0',
#  's 720 279 729 290 0',
#  '? 730 279 740 294 0',
#  'v 1042 282 1056 291 0',
#  'W 249 225 259 240 0',
#  'h 249 225 268 240 0',
#  'i 269 225 278 240 0',
#  'c 280 225 282 240 0',
#  'h 284 225 304 240 0',
#  'i 311 225 314 240 0',
#  's 315 225 324 236 0',
#  't 330 225 336 240 0',
#  'h 337 225 346 240 0',
#  'e 347 225 357 236 0',
#  'b 364 225 374 240 0',
#  'e 375 225 385 236 0',
#  's 386 225 395 236 0',
#  't 396 225 401 240 0',
#  'e 407 225 428 240 0',
#  'd 418 221 428 240 0',
#  'g 430 221 439 236 0',
#  'e 441 225 451 236 0',
#  'd 457 225 467 240 0',
#  'e 468 225 479 236 0',
#  't 479 225 485 240 0',
#  'e 485 225 495 236 0',
#  'c 492 225 502 240 0',
#  't 496 225 506 236 0',
#  'i 506 225 515 240 0',
#  'o 516 225 527 236 0',
#  'n 528 225 537 236 0',
#  'a 544 225 554 236 0',
#  'l 556 225 558 240 0',
#  'g 560 221 569 236 0',
#  'o 571 225 581 236 0',
#  'r 578 221 587 240 0',
#  'i 582 225 598 240 0',
#  't 599 225 608 240 0',
#  'h 605 221 617 240 0',
#  'm 610 225 625 236 0',
#  'O 632 225 646 240 0',
#  'p 648 221 658 236 0',
#  'e 659 225 669 236 0',
#  'n 670 225 679 236 0',
#  'c 681 225 691 236 0',
#  'v 691 225 700 236 0',
#  '? 701 225 711 240 0',
#  'v 1042 227 1056 236 0',
#  'W 249 171 259 186 0',
#  'h 249 171 268 186 0',
#  'i 269 171 278 186 0',
#  'c 280 171 282 186 0',
#  'h 284 171 304 186 0',
#  'i 311 171 314 186 0',
#  's 315 171 324 182 0',
#  'b 331 171 341 186 0',
#  'e 342 171 352 182 0',
#  't 352 171 364 186 0',
#  't 359 171 369 186 0',
#  'e 364 171 374 182 0',
#  'r 376 171 382 182 0',
#  'C 388 171 401 186 0',
#  'a 402 171 412 182 0',
#  'n 413 171 423 182 0',
#  'n 424 171 434 182 0',
#  'y 435 167 445 182 0',
#  'a 451 171 461 182 0',
#  'n 462 171 472 182 0',
#  'd 473 171 482 186 0',
#  'S 490 171 502 186 0',
#  'o 503 171 513 182 0',
#  'b 510 171 520 186 0',
#  'e 515 171 524 186 0',
#  'l 525 171 539 186 0',
#  '? 541 171 551 186 0',
#  'v 1042 173 1056 182 0',
#  'F 999 135 1007 146 0',
#  'e 1008 135 1015 143 0',
#  'e 1013 135 1023 146 0',
#  'd 1016 135 1032 146 0',
#  'b 1032 135 1040 146 0',
#  'a 1033 135 1049 146 0',
#  'c 1049 135 1056 143 0',
#  'k 1057 135 1064 146 0',
#  'h 250 53 255 70 0',
#  't 250 57 258 70 0',
#  't 259 53 278 70 0',
#  'p 271 53 278 70 0',
#  's 279 57 287 67 0',
#  ': 288 57 291 66 0',
#  '/ 292 57 297 70 0',
#  '/ 297 57 302 70 0',
#  'm 302 53 314 70 0',
#  'e 302 57 335 70 0',
#  'd 325 53 334 70 0',
#  'i 336 57 339 70 0',
#  'u 340 57 348 67 0',
#  'm 350 57 363 67 0',
#  '. 365 57 368 59 0',
#  'c 369 57 387 67 0',
#  'o 379 53 388 70 0',
#  'm 388 57 401 67 0',
#  '> 407 58 411 66 0',
#  'c 418 57 436 67 0',
#  'o 430 53 439 70 0',
#  'm 437 57 450 67 0',
#  'p 450 53 459 70 0',
#  'a 451 53 469 67 0',
#  'r 467 53 476 70 0',
#  'i 471 57 479 70 0',
#  'n 480 57 489 67 0',
#  ...]
